# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# 1. PREPARACIÓ DE DADES (Suposem que ja tens el teu Excel carregat a 'df')
# Seleccionem les columnes que fan de INPUT (X)
features = ['Renda_Capita', 'Any_Construccio', 'Superficie', 'Consum_Anual']
X = df[features]

# Seleccionem la columna que volem PREDIR (y) - Ha de ser 0 o 1
y = df['Es_Vulnerable']

# 2. NORMALITZACIÓ (Vital per a Xarxes Neuronals!)
# Les xarxes no entenen bé si barreges anys (1990) amb euros (15000). Ho posem tot a la mateixa escala.
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Separem en Entrenament (80%) i Test (20%)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 3. DEFINIM L'ARQUITECTURA (El "Cervell")
model = Sequential()

# Capa d'entrada i primera oculta
# input_dim=4 perquè tenim 4 variables (Renda, Any, Sup, Consum)
model.add(Dense(64, activation='relu', input_dim=X_train.shape[1]))

# Segona capa oculta (per aprendre patrons més complexos)
model.add(Dense(32, activation='relu'))

# Capa de "Dropout" (Apaga neurones a l'atzar per evitar que memoritzi l'examen)
model.add(Dropout(0.2))

# Capa de sortida (Només 1 neurona: Si/No)
# Sigmoid: converteix el resultat en una probabilitat entre 0 i 1
model.add(Dense(1, activation='sigmoid'))

# 4. COMPILACIÓ (Com aprèn?)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 5. ENTRENAMENT
print("🚀 Entrenant la xarxa...")
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1)

print("✅ Model entrenat!")
